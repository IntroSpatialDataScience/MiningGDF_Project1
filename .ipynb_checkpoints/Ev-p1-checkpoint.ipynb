# %% [markdown]
# # Evaluación - parte 1

# %%
import os
import geopandas as gpd
from  fiona import listlayers
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Exercise 1

# %% [markdown]
#
# ### 1. Use two maps of points.

# %%
peru_health = "https://github.com/IntroSpatialDataScience/MiningGDF_Project1/raw/main/maps/peru_health_24891.gpkg"
ports = "https://github.com/IntroSpatialDataScience/MiningGDF_Project1/raw/main/data/UpdatedPub150.csv"

# %%
listlayers(ports)
# Out:
# ['UpdatedPub150']

# %%
healthsites =gpd.read_file(peru_health,layer='healthsites')
portsFile =gpd.read_file(ports,layer='UpdatedPub150')

# %%
portsFile
# Out:
#      World Port Index Number                    Region Name  \
# 0                       7950  United States E Coast -- 6585
# 1                      52235              Sulawesi -- 51970
# 2                      47620            Madagascar -- 47350
# 3                      47360            Madagascar -- 47350
# 4                      47020              Tanzania -- 46965
# ...                      ...                            ...
# 3819                   51560               Sarawak -- 51550
# 3820                   51635                Brunei -- 51610
# 3821                   48475                  Iran -- 48410
# 3822                   48264  United Arab Emirates -- 48260
# 3823                   48480                  Iran -- 48410
#
#                      Main Port Name Alternate Port Name UN/LOCODE  \
# 0                            Maurer
# 1             Mangkasa Oil Terminal
# 2                           Iharana
# 3                           Andoany
# 4                       Chake Chake
# ...                             ...                 ...       ...
# 3819                        Kuching                        MY KCH
# 3820                          Lumut                        BN LUM
# 3821         Bandar-E Pars Terminal           Assaluyeh
# 3822                      Mina Saqr      Ras Al Khaimah    AE MSA
# 3823  Jazireh-Ye Lavan Oil Terminal        Lavan Island    IR LVP
#
#               Country Code                            World Water Body  \
# 0            United States                        North Atlantic Ocean
# 1                Indonesia  Teluk Bone; Banda Sea; South Pacific Ocean
# 2               Madagascar                                Indian Ocean
# 3               Madagascar            Mozambique Channel; Indian Ocean
# 4                 Tanzania                                Indian Ocean
# ...                    ...                                         ...
# 3819              Malaysia        South China Sea; North Pacific Ocean
# 3820                Brunei        South China Sea; North Pacific Ocean
# 3821                  Iran                  Persian Gulf; Indian Ocean
# 3822  United Arab Emirates                  Persian Gulf; Indian Ocean
# 3823                  Iran                  Persian Gulf; Indian Ocean
#
#                        Sailing Direction or Publication  \
# 0     U.S. Coast Pilot 2 - Atlantic Coast: Cape Cod ...
# 1     Sailing Directions Pub. 163 (Enroute) - Borneo...
# 2     Sailing Directions Pub. 171 (Enroute) - East A...
# 3     Sailing Directions Pub. 171 (Enroute) - East A...
# 4     Sailing Directions Pub. 171 (Enroute) - East A...
# ...                                                 ...
# 3819  Sailing Directions Pub. 163 (Enroute) - Borneo...
# 3820  Sailing Directions Pub. 163 (Enroute) - Borneo...
# 3821  Sailing Directions Pub. 172 (Enroute) - Red Se...
# 3822  Sailing Directions Pub. 172 (Enroute) - Red Se...
# 3823  Sailing Directions Pub. 172 (Enroute) - Red Se...
#
#                                        Publication Link  \
# 0     https://nauticalcharts.noaa.gov/publications/c...
# 1     https://msi.geo.nga.mil/api/publications/downl...
# 2     https://msi.geo.nga.mil/api/publications/downl...
# 3     https://msi.geo.nga.mil/api/publications/downl...
# 4     https://msi.geo.nga.mil/api/publications/downl...
# ...                                                 ...
# 3819  https://msi.geo.nga.mil/api/publications/downl...
# 3820  https://msi.geo.nga.mil/api/publications/downl...
# 3821  https://msi.geo.nga.mil/api/publications/downl...
# 3822  https://msi.geo.nga.mil/api/publications/downl...
# 3823  https://msi.geo.nga.mil/api/publications/downl...
#
#      Standard Nautical Chart  ... Supplies - Diesel Oil  \
# 0                      12331  ...                   Yes
# 1                             ...                    No
# 2                      61560  ...                    No
# 3                      61420  ...                    No
# 4                      61200  ...                    No
# ...                      ...  ...                   ...
# 3819                   71350  ...                   Yes
# 3820                   71330  ...                   Yes
# 3821                          ...               Unknown
# 3822                   62458  ...                   Yes
# 3823                   62481  ...                   Yes
#
#      Supplies - Aviation Fuel Supplies - Deck Supplies - Engine  \
# 0                     Unknown             Yes               Yes
# 1                     Unknown              No                No
# 2                     Unknown              No                No
# 3                     Unknown              No                No
# 4                     Unknown              No                No
# ...                       ...             ...               ...
# 3819                  Unknown             Yes               Yes
# 3820                  Unknown         Unknown           Unknown
# 3821                  Unknown         Unknown           Unknown
# 3822                  Unknown         Unknown           Unknown
# 3823                  Unknown              No                No
#
#              Repairs Dry Dock  Railway   Latitude   Longitude geometry
# 0           Moderate  Unknown  Unknown  40.533333      -74.25     None
# 1               None  Unknown  Unknown  -2.733333  121.066667     None
# 2     Emergency Only  Unknown  Unknown     -13.35          50     None
# 3     Emergency Only  Unknown  Unknown      -13.4        48.3     None
# 4            Unknown  Unknown  Unknown      -5.25   39.766667     None
# ...              ...      ...      ...        ...         ...      ...
# 3819         Limited    Small    Small   1.566667      110.35     None
# 3820  Emergency Only  Unknown  Unknown   4.716667      114.45     None
# 3821         Unknown  Unknown  Unknown  27.533333   52.533333     None
# 3822        Moderate  Unknown  Unknown  25.983333       56.05     None
# 3823            None  Unknown  Unknown  26.783333   53.333333     None
#
# [3824 rows x 108 columns]

# %%
#rename
portsFile.rename(columns={'Main Port Name':'portName'},inplace=True)
#subset
portsFile=portsFile.loc[:,['portName', 'Country Code','Latitude', 'Longitude']]

# %%
#spatial points (unprojected)
seaports=gpd.GeoDataFrame(data=portsFile.copy(),
                           geometry=gpd.points_from_xy(portsFile.Longitude,
                                                       portsFile.Latitude), 
                          crs=4326)# notice it is unprojected

# %%
seaports[seaports['Country Code']=='Peru']
# Out:
#                               portName Country Code    Latitude   Longitude  \
# 919           La Pampilla Oil Terminal         Peru  -11.933333  -77.133333
# 946                            Iquitos         Peru       -3.75  -73.233333
# 952                            Chancay         Peru  -11.583333      -77.25
# 991                        Puerto Supe         Peru       -10.8      -77.75
# 1004                         Salaverry         Peru   -8.233333  -78.983333
# 1502              Conchan Oil Terminal         Peru  -12.166667         -77
# 1655                 Bahia San Nicolas         Peru      -15.25  -75.233333
# 1910  Punta Lobitos (Bahia De Huarmey)         Peru       -10.1  -78.166667
# 1976                Puerto De Chimbote         Peru   -9.083333  -78.616667
# 1987                          Pimental         Peru   -6.833333  -79.933333
# 2188                 Bahia De Matarani         Peru         -17  -72.116667
# 2203                    Bahia De Ancon         Peru      -11.75  -77.183333
# 2204                    Caleta Lobitos         Peru       -4.45  -81.283333
# 2216                        Puerto Ilo         Peru  -17.633333  -71.366667
# 2219                Puerto Cabo Blanco         Peru       -4.25  -81.233333
# 2221                  Puerto De Huacho         Peru  -11.116667  -77.616667
# 2223                 Puerto Del Callao         Peru      -12.05      -77.15
# 3596                            Talara         Peru   -4.583333  -81.283333
# 3633                    Puerto Bayovar         Peru   -5.833333      -81.05
# 3634                             Paita         Peru   -5.083333  -81.116667
#
#                          geometry
# 919   POINT (-77.13333 -11.93333)
# 946    POINT (-73.23333 -3.75000)
# 952   POINT (-77.25000 -11.58333)
# 991   POINT (-77.75000 -10.80000)
# 1004   POINT (-78.98333 -8.23333)
# 1502  POINT (-77.00000 -12.16667)
# 1655  POINT (-75.23333 -15.25000)
# 1910  POINT (-78.16667 -10.10000)
# 1976   POINT (-78.61667 -9.08333)
# 1987   POINT (-79.93333 -6.83333)
# 2188  POINT (-72.11667 -17.00000)
# 2203  POINT (-77.18333 -11.75000)
# 2204   POINT (-81.28333 -4.45000)
# 2216  POINT (-71.36667 -17.63333)
# 2219   POINT (-81.23333 -4.25000)
# 2221  POINT (-77.61667 -11.11667)
# 2223  POINT (-77.15000 -12.05000)
# 3596   POINT (-81.28333 -4.58333)
# 3633   POINT (-81.05000 -5.83333)
# 3634   POINT (-81.11667 -5.08333)

# %%
seaports_pe=seaports[seaports['Country Code']=='Peru'].copy()
seaports_pe
# Out:
#                               portName Country Code    Latitude   Longitude  \
# 919           La Pampilla Oil Terminal         Peru  -11.933333  -77.133333
# 946                            Iquitos         Peru       -3.75  -73.233333
# 952                            Chancay         Peru  -11.583333      -77.25
# 991                        Puerto Supe         Peru       -10.8      -77.75
# 1004                         Salaverry         Peru   -8.233333  -78.983333
# 1502              Conchan Oil Terminal         Peru  -12.166667         -77
# 1655                 Bahia San Nicolas         Peru      -15.25  -75.233333
# 1910  Punta Lobitos (Bahia De Huarmey)         Peru       -10.1  -78.166667
# 1976                Puerto De Chimbote         Peru   -9.083333  -78.616667
# 1987                          Pimental         Peru   -6.833333  -79.933333
# 2188                 Bahia De Matarani         Peru         -17  -72.116667
# 2203                    Bahia De Ancon         Peru      -11.75  -77.183333
# 2204                    Caleta Lobitos         Peru       -4.45  -81.283333
# 2216                        Puerto Ilo         Peru  -17.633333  -71.366667
# 2219                Puerto Cabo Blanco         Peru       -4.25  -81.233333
# 2221                  Puerto De Huacho         Peru  -11.116667  -77.616667
# 2223                 Puerto Del Callao         Peru      -12.05      -77.15
# 3596                            Talara         Peru   -4.583333  -81.283333
# 3633                    Puerto Bayovar         Peru   -5.833333      -81.05
# 3634                             Paita         Peru   -5.083333  -81.116667
#
#                          geometry
# 919   POINT (-77.13333 -11.93333)
# 946    POINT (-73.23333 -3.75000)
# 952   POINT (-77.25000 -11.58333)
# 991   POINT (-77.75000 -10.80000)
# 1004   POINT (-78.98333 -8.23333)
# 1502  POINT (-77.00000 -12.16667)
# 1655  POINT (-75.23333 -15.25000)
# 1910  POINT (-78.16667 -10.10000)
# 1976   POINT (-78.61667 -9.08333)
# 1987   POINT (-79.93333 -6.83333)
# 2188  POINT (-72.11667 -17.00000)
# 2203  POINT (-77.18333 -11.75000)
# 2204   POINT (-81.28333 -4.45000)
# 2216  POINT (-71.36667 -17.63333)
# 2219   POINT (-81.23333 -4.25000)
# 2221  POINT (-77.61667 -11.11667)
# 2223  POINT (-77.15000 -12.05000)
# 3596   POINT (-81.28333 -4.58333)
# 3633   POINT (-81.05000 -5.83333)
# 3634   POINT (-81.11667 -5.08333)

# %%
# reset indexes
seaports_pe.reset_index(drop=True, inplace=True)

# reprojecting
seaports_pe_24891=seaports_pe.to_crs(24891) # projected crs

# %%
health_clinic = healthsites[healthsites.tipo=="clinic"]

# %%
base=health_clinic.plot(color='red',marker="^",markersize=4)
seaports_pe_24891.plot(ax=base,alpha=0.8,markersize=5)
plt.show()

# %% [markdown]
# ### 2. Compute the distance matrix for both maps.

# %% [markdown]
# ### 3. Select one row of the distance matrix, and plot the two points with the minimal distance on top of the country of your choosing.
